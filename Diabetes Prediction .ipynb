# %% [markdown]
# # Diabetes Prediction
#
# Predicts whether a person has diabetes disease or not
#
# Dataset Link:https://www.kaggle.com/johndasilva/diabetes

# %%
# Importing essential libraries
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("kaggle_diabetes.csv")

# %% [markdown]
# ## Exploring The Dataset

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
dataset.tail()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0

# %%
# Returns number of rows and columns of the dataset
dataset.shape
# Out:
# (2000, 9)

# %%
# Returns an object with all of the column headers 
dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Returns different datatypes for each columns (float, int, string, bool, etc.)
dataset.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Returns basic information on all columns
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
# Returns basic statistics on numeric columns
dataset.describe().T
# Out:
#                            count       mean         std     min     25%  \
# Pregnancies               2000.0    3.70350    3.306063   0.000   1.000
# Glucose                   2000.0  121.18250   32.068636   0.000  99.000
# BloodPressure             2000.0   69.14550   19.188315   0.000  63.500
# SkinThickness             2000.0   20.93500   16.103243   0.000   0.000
# Insulin                   2000.0   80.25400  111.180534   0.000   0.000
# BMI                       2000.0   32.19300    8.149901   0.000  27.375
# DiabetesPedigreeFunction  2000.0    0.47093    0.323553   0.078   0.244
# Age                       2000.0   33.09050   11.786423  21.000  24.000
# Outcome                   2000.0    0.34200    0.474498   0.000   0.000
#
#                               50%      75%     max
# Pregnancies                 3.000    6.000   17.00
# Glucose                   117.000  141.000  199.00
# BloodPressure              72.000   80.000  122.00
# ...

# %%
# Returns true for a column having null values, else false
dataset.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
# Returns the sum of the total null value rows
dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#importing essential library for visualization of dataset
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#For checking the null values
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# Have been visualized using the missingno library for the visualization of missing observations.
# Plotting 
import missingno as msno
msno.bar(dataset)
# Out:
# <AxesSubplot:>

# %%
# Renaming the DiabetesPedigreeFunction column as DPF
dataset = dataset.rename(columns={'DiabetesPedigreeFunction':'DPF'})
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 0            2      138             62             35        0  33.6  0.127
# 1            0       84             82             31      125  38.2  0.233
# 2            0      145              0              0        0  44.2  0.630
# 3            0      135             68             42      250  42.3  0.365
# 4            1      139             62             41      480  40.7  0.536
#
#    Age  Outcome
# 0   47        1
# 1   23        0
# 2   31        1
# 3   24        1
# 4   21        0

# %%
# Renaming the DiabetesPedigreeFunction column as DPF
dataset = dataset.rename(columns={'Outcome':'Target'})
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 0            2      138             62             35        0  33.6  0.127
# 1            0       84             82             31      125  38.2  0.233
# 2            0      145              0              0        0  44.2  0.630
# 3            0      135             68             42      250  42.3  0.365
# 4            1      139             62             41      480  40.7  0.536
#
#    Age  Target
# 0   47       1
# 1   23       0
# 2   31       1
# 3   24       1
# 4   21       0

# %%
# The distribution of the outcome variable ie target or dependent feature in the data was examined and visualized over here.
f,ax=plt.subplots(1,2,figsize=(18,8))
dataset['Target'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Has vs Not Has')
ax[0].set_ylabel('')
sns.countplot('Target',data=dataset,ax=ax[1])
ax[1].set_title('Has vs Not Has')
plt.show()
# Out:
# c:\users\neeraj\.conda\envs\diabetes_pred\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Correlation matrix graph of the data set
f, ax = plt.subplots(figsize= [20,15])
sns.heatmap(dataset.corr(), annot=True, fmt=".2f", ax=ax, cmap = "magma" )
ax.set_title("Correlation Matrix", fontsize=20)
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
# Replacing the 0 values from ['Glucose','BloodPressure','SkinThickness','Insulin','BMI'] by NaN
dataset_copy = dataset.copy(deep=True)
dataset_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = dataset_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)
dataset_copy.isnull().sum()
# Out:
# Pregnancies        0
# Glucose           13
# BloodPressure     90
# SkinThickness    573
# Insulin          956
# BMI               28
# DPF                0
# Age                0
# Target             0
# dtype: int64

# %%
#For checking the null values
sns.heatmap(dataset_copy.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# Have been visualized using the missingno library for the visualization of missing observations.
# Plotting 
import missingno as msno
msno.bar(dataset_copy)
# Out:
# <AxesSubplot:>

# %%
# To fill these Nan values the data distribution needs to be understood
# Plotting histogram of dataset before replacing NaN values
p = dataset_copy.hist(figsize = (15,15))

# %%
# Replacing NaN value by mean, median depending upon distribution
dataset_copy['Glucose'].fillna(dataset_copy['Glucose'].mean(), inplace=True)
dataset_copy['BloodPressure'].fillna(dataset_copy['BloodPressure'].mean(), inplace=True)
dataset_copy['SkinThickness'].fillna(dataset_copy['SkinThickness'].median(), inplace=True)
dataset_copy['Insulin'].fillna(dataset_copy['Insulin'].median(), inplace=True)
dataset_copy['BMI'].fillna(dataset_copy['BMI'].median(), inplace=True)

# %%
# Plotting histogram of dataset after replacing NaN values
p = dataset_copy.hist(figsize=(15,15))

# %%
dataset_copy.isnull().sum()
# Out:
# Pregnancies      0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# DPF              0
# Age              0
# Target           0
# dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop(columns='Target')
y = dataset['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
print('X_train size: {}, X_test size: {}'.format(X_train.shape, X_test.shape))
# Out:
# X_train size: (1600, 8), X_test size: (400, 8)

# %%
# Feature Scaling  --> So that difference betwen values do not affect our model 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Using GridSearchCV to find the best algorithm for this problem
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# Creating a function to calculate best model for this problem
def find_best_model(X, y):
    models = {
        'logistic_regression': {
            'model': LogisticRegression(solver='lbfgs', multi_class='auto'),
            'parameters': {
                'C': [1,5,10]
               }
        },
        
        'decision_tree': {
            'model': DecisionTreeClassifier(splitter='best'),
            'parameters': {
                'criterion': ['gini', 'entropy'],
                'max_depth': [5,10]
            }
        },
        
        'random_forest': {
            'model': RandomForestClassifier(criterion='gini'),
            'parameters': {
                'n_estimators': [10,15,20,50,100,200]
            }
        },
        
        'svm': {
            'model': SVC(gamma='auto'),
            'parameters': {
                'C': [1,10,20],
                'kernel': ['rbf','linear']
            }
        }

    }
    
    scores = [] 
    cv_shuffle = ShuffleSplit(n_splits=5, test_size=0.20, random_state=0)
        
    for model_name, model_params in models.items():
        gs = GridSearchCV(model_params['model'], model_params['parameters'], cv = cv_shuffle, return_train_score=False)
        gs.fit(X, y)
        scores.append({
            'model': model_name,
            'best_parameters': gs.best_params_,
            'score': gs.best_score_
        })
        
    return pd.DataFrame(scores, columns=['model','best_parameters','score'])

find_best_model(X_train, y_train)
# Out:
#                  model                         best_parameters     score
# 0  logistic_regression                               {'C': 10}  0.763125
# 1        decision_tree  {'criterion': 'gini', 'max_depth': 10}  0.897500
# 2        random_forest                    {'n_estimators': 20}  0.949375
# 3                  svm              {'C': 20, 'kernel': 'rbf'}  0.869375

# %% [markdown]
# ##### Note: Since the Random Forest algorithm has the highest accuracy, we futher fine tune the model using hyperparameter optimization.

# %%
# Using cross_val_score for gaining average accuracy
from sklearn.model_selection import cross_val_score
scores = cross_val_score(RandomForestClassifier(n_estimators=20, random_state=0), X_train, y_train, cv=5)
print(scores)
print('Average Accuracy : {}%'.format(round(sum(scores)*100/len(scores)), 3))
# Out:
# [0.928125 0.971875 0.94375  0.95625  0.95    ]
# Average Accuracy : 95%

# %%
# Creating Random Forest Model
classifier = RandomForestClassifier(n_estimators=20, random_state=0)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)

# %% [markdown]
# # Model Evaluation

# %%
# Creating a confusion matrix
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[272,   0],
#        [  5, 123]], dtype=int64)

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10,7))
p = sns.heatmap(cm, annot=True, cmap="Blues", fmt='g')
plt.title('Confusion matrix for Random Forest Classifier Model - Test Data')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

# %%
# Accuracy Score
score = round(accuracy_score(y_test, y_pred),4)*100
print("Accuracy on test set: {}%".format(score))
# Out:
# Accuracy on test set: 98.75%

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       272
#            1       1.00      0.96      0.98       128
#
#     accuracy                           0.99       400
#    macro avg       0.99      0.98      0.99       400
# weighted avg       0.99      0.99      0.99       400

# %%
# Creating a confusion matrix for training set
y_train_pred = classifier.predict(X_train)
cm = confusion_matrix(y_train, y_train_pred)
cm
# Out:
# array([[1044,    0],
#        [   1,  555]], dtype=int64)

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10,7))
p = sns.heatmap(cm, annot=True, cmap="Blues", fmt='g')
plt.title('Confusion matrix for Random Forest Classifier Model - Train Set')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.show()

# %%
# Accuracy Score
score = round(accuracy_score(y_train, y_train_pred),4)*100
print("Accuracy on trainning set: {}%".format(score))
# Out:
# Accuracy on trainning set: 99.94%

# %%
# Classification Report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1044
#            1       1.00      1.00      1.00       556
#
#     accuracy                           1.00      1600
#    macro avg       1.00      1.00      1.00      1600
# weighted avg       1.00      1.00      1.00      1600

# %% [markdown]
# # Prediction

# %%
# Creating a function for prediction
def predict_diabetes(Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DPF, Age):
    preg = int(Pregnancies)
    glucose = float(Glucose)
    bp = float(BloodPressure)
    st = float(SkinThickness)
    insulin = float(Insulin)
    bmi = float(BMI)
    dpf = float(DPF)
    age = int(Age)

    x = [[preg, glucose, bp, st, insulin, bmi, dpf, age]]
    x = sc.transform(x)

    return classifier.predict(x)

# %%
# Prediction 1
# Input sequence: Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DPF, Age
prediction = predict_diabetes(2, 81, 72, 15, 76, 30.1, 0.547, 25)[0]
if prediction:
    print('Oops! You have diabetes.')
else:
    print("Great! You don't have diabetes.")
# Out:
# Great! You don't have diabetes.

# %%
# Prediction 2
# Input sequence: Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DPF, Age
prediction = predict_diabetes(1, 117, 88, 24, 145, 34.5, 0.403, 40)[0]
if prediction:
    print('Oops! You have diabetes.')
else:
    print("Great! You don't have diabetes.")
# Out:
# Great! You don't have diabetes.

# %% [markdown]
# # Saving the Pickel file of classifier for Prediction in Web App

# %%
# Importing Essential library
import pickle

# %%
# file name
file = open('classifier_model_for_app.pkl', 'wb')

# dump information to that file
pickle.dump(classifier, file)

# %%
#making the prediction using pickled model
loaded_model = open('classifier_model_for_app.pkl','rb')
rf_loaded_model = pickle.load(loaded_model)

# %%
rf_loaded_pred=rf_loaded_model.predict(X_test)

# %%
from sklearn.metrics import recall_score,precision_score

# %%
print("Recall With loaded model : {}".format(recall_score(y_test,rf_loaded_pred)))

print("Precision with loaded model: {}".format(precision_score(y_test,rf_loaded_pred)))

print("Accuracy Score with loaded model : {}".format(accuracy_score(y_test,rf_loaded_pred)))
# Out:
# Recall With loaded model : 0.9609375
# Precision with loaded model: 1.0
# Accuracy Score with loaded model : 0.9875
